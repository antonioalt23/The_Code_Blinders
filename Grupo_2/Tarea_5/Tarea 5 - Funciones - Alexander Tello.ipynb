# %% [markdown]
# ## Solución Tarea 5 - Alexander Max Tello Fuentes

# %% [markdown]
# #### Desarrollar una función que tome la data consumo_comedor y que me entregue tres tipos de dataframes: la totalidad de consumo y el monto total por tipo de pedido MENU ECONOMICO y DESAYUNO, me entregue la data con aquellos usuarios que no cumplen con tener un código de usuario de tamaño 4 y la cantidad de consumo por usuario dividido en el tipo de consumo.

# %%
import numpy as np
import pandas as pd 
from pandas import DataFrame,Series

# %%
consumo_comedor = pd.read_excel(r"The_Code_Blinders/data/consumo_comedor.xls").drop(['Unnamed: 1'],axis = 1)
consumo_comedor.head()
# Out:
#               fechaact            fechaBol  nroEmp  CodigoEmp  usuario  \
# 0  2021-02-15 00:00:00 2021-02-15 12:00:47   126.0     2473.0   2473.0
# 1                  NaN 2021-02-15 12:03:52   147.0     3214.0   3214.0
# 2                  NaN 2021-02-15 12:03:57   315.0     3200.0   3200.0
# 3                  NaN 2021-02-15 12:04:11   322.0     3955.0   3955.0
# 4                  NaN 2021-02-15 12:04:29   299.0     3963.0   3963.0
#
#    cantidad        Concepto  monto Total
# 0       1.0  MENU ECONOMICO            8
# 1       1.0  MENU ECONOMICO            8
# 2       1.0  MENU ECONOMICO            8
# 3       1.0  MENU ECONOMICO            8
# 4       1.0  MENU ECONOMICO            8

# %%
def consumo_comedor (retorno = 'Concepto', modo = 'DataFrame'):
    x = pd.read_excel(r"The_Code_Blinders/data/consumo_comedor.xls").drop(['Unnamed: 1'],axis = 1)
    
    if retorno == "Concepto":
        tabla = x.groupby(['Concepto'])['cantidad','monto Total'].sum()
        tabla1 = pd.DataFrame(tabla.agg(['sum']).values, columns = ['cantidad', 'monto Total'],index=['TOTAL'])
        tabla = tabla.append(tabla1)
        if modo == 'DataFrame':
            return tabla
        elif modo == 'Dic':
            return tabla.to_dict('dict')
        else:
            print('Error, inserta el MODO correcto')
    elif retorno == "Usuarios_Raros":
        tabla2 = x[(x['usuario']<1000) | (x['usuario']>9999)]
        tabla2 = tabla2[['usuario','cantidad','Concepto','monto Total']]
        if modo == 'DataFrame':
            return tabla2
        elif modo == 'Dic':
            return tabla2.to_dict('dict')
        else:
            print('Error, inserta el MODO correcto')
    elif retorno == "Por_Usuario":
        tabla3 = x.groupby(['usuario','Concepto'])['cantidad','monto Total'].sum().reset_index()
        if modo == 'DataFrame':
            return tabla3
        elif modo == 'Dic':
            return tabla3.to_dict('dict')
        else:
            print('Error, inserta el MODO correcto')
    else:
        print('Error, inserta el NOMBRE correcto')

# %%
consumo_comedor()
# Out:
# <ipython-input-230-8191ed6cd973>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tabla = x.groupby(['Concepto'])['cantidad','monto Total'].sum()
#                 cantidad  monto Total
# DESAYUNO           367.0       1468.0
# MENU ECONOMICO    1491.0      11928.0
# TOTAL             1858.0      13396.0

# %%
consumo_comedor('Concepto')
# Out:
# <ipython-input-230-8191ed6cd973>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tabla = x.groupby(['Concepto'])['cantidad','monto Total'].sum()
#                 cantidad  monto Total
# DESAYUNO           367.0       1468.0
# MENU ECONOMICO    1491.0      11928.0
# TOTAL             1858.0      13396.0

# %%
consumo_comedor('Concepto','Dic')
# Out:
# <ipython-input-230-8191ed6cd973>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tabla = x.groupby(['Concepto'])['cantidad','monto Total'].sum()
# {'cantidad': {'DESAYUNO': 367.0, 'MENU ECONOMICO': 1491.0, 'TOTAL': 1858.0},
#  'monto Total': {'DESAYUNO': 1468.0,
#   'MENU ECONOMICO': 11928.0,
#   'TOTAL': 13396.0}}

# %%
consumo_comedor('Usuarios_Raros')
# Out:
#          usuario  cantidad        Concepto  monto Total
# 278          3.0       1.0  MENU ECONOMICO            8
# 924   21403730.0       1.0  MENU ECONOMICO            8
# 1624       340.0       1.0  MENU ECONOMICO            8
# 1699        31.0       1.0        DESAYUNO            4
# 1848    373957.0       1.0  MENU ECONOMICO            8

# %%
consumo_comedor('Usuarios_Raros','Dic')
# Out:
# {'usuario': {278: 3.0,
#   924: 21403730.0,
#   1624: 340.0,
#   1699: 31.0,
#   1848: 373957.0},
#  'cantidad': {278: 1.0, 924: 1.0, 1624: 1.0, 1699: 1.0, 1848: 1.0},
#  'Concepto': {278: 'MENU ECONOMICO',
#   924: 'MENU ECONOMICO',
#   1624: 'MENU ECONOMICO',
#   1699: 'DESAYUNO',
#   1848: 'MENU ECONOMICO'},
#  'monto Total': {278: 8, 924: 8, 1624: 8, 1699: 4, 1848: 8}}

# %%
consumo_comedor('Por_Usuario')
# Out:
# <ipython-input-230-8191ed6cd973>:24: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tabla3 = x.groupby(['usuario','Concepto'])['cantidad','monto Total'].sum().reset_index()
#         usuario        Concepto  cantidad  monto Total
# 0           3.0  MENU ECONOMICO       1.0            8
# 1          31.0        DESAYUNO       1.0            4
# 2         340.0  MENU ECONOMICO       1.0            8
# 3        1563.0  MENU ECONOMICO       3.0           24
# 4        1567.0  MENU ECONOMICO       1.0            8
# ..          ...             ...       ...          ...
# 196      7048.0  MENU ECONOMICO       2.0           16
# 197      7053.0  MENU ECONOMICO       1.0            8
# 198      8089.0  MENU ECONOMICO       1.0            8
# 199    373957.0  MENU ECONOMICO       1.0            8
# 200  21403730.0  MENU ECONOMICO       1.0            8
#
# [201 rows x 4 columns]

# %%
consumo_comedor('Por_Usuario','Dic')
# Out:
# <ipython-input-230-8191ed6cd973>:24: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tabla3 = x.groupby(['usuario','Concepto'])['cantidad','monto Total'].sum().reset_index()
# {'usuario': {0: 3.0,
#   1: 31.0,
#   2: 340.0,
#   3: 1563.0,
#   4: 1567.0,
#   5: 2140.0,
#   6: 2245.0,
#   7: 2254.0,
#   8: 2263.0,
#   9: 2339.0,
#   10: 2382.0,
#   11: 2411.0,
#   12: 2425.0,
#   13: 2446.0,
#   14: 2473.0,
#   15: 2480.0,
#   16: 2492.0,
#   17: 2500.0,
#   18: 2504.0,
#   19: 2506.0,
#   20: 2514.0,
#   21: 2516.0,
#   22: 2522.0,
#   23: 2534.0,
#   24: 2536.0,
#   25: 2537.0,
#   26: 2553.0,
#   27: 2558.0,
#   28: 2570.0,
#   29: 2573.0,
#   30: 2578.0,
#   31: 2580.0,
#   32: 2581.0,
#   33: 3030.0,
#   34: 3035.0,
#   35: 3035.0,
#   36: 3037.0,
#   37: 3037.0,
#   38: 3039.0,
#   39: 3039.0,
#   40: 3041.0,
#   41: 3045.0,
#   42: 3050.0,
#   43: 3063.0,
#   44: 3089.0,
#   45: 3093.0,
# ...

# %%
consumo_comedor('x','Dic')
# Out:
# Error, inserta el NOMBRE correcto

# %%
consumo_comedor('Concepto','DIC')
# Out:
# Error, inserta el MODO correcto
# <ipython-input-230-8191ed6cd973>:5: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   tabla = x.groupby(['Concepto'])['cantidad','monto Total'].sum()
