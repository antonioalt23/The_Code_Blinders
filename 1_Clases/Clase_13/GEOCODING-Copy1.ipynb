# %% [markdown]
# # Qué es geocoding?

# %% [markdown]
# **Este material está basado en la documentacion de Google Maps API [LINK](https://developers.google.com/maps/documentation/geocoding/overview).**
# 1. **Geocoding** es el proceso de convertir direcciones como "Avenida Alfonso Ugarte 1227, Cercado de Lima 15001" [Sitio](https://www.google.com/maps/place/Primer+Colegio+Nacional+de+la+Rep%C3%BAblica+Nuestra+Se%C3%B1ora+de+Guadalupe/@-12.0553202,-77.0433608,17z/data=!3m1!4b1!4m5!3m4!1s0x9105c8c44eaaaaab:0xe4ca2a4756a547df!8m2!3d-12.0553202!4d-77.0411721),
#    en coordenadas geográficas (como latitud -12.0552362536 y longitud -77.0412042), que puede usar para colocar        marcadores en un mapa o posicionar el mapa.
#
# 2. **Inverse Geocoding** es el proceso de convertir coordenadas geográficas en una dirección legible por humanos.

# %% [markdown]
# **El Geocoding API** proporciona una forma directa de acceder a estos servicios
# a través de una solicitud HTTP. El siguiente ejemplo utiliza el servicio de codificación
# geográfica a través de la API de JavaScript de Maps para demostrar la funcionalidad básica. [video](https://www.youtube.com/watch?v=hExRDVZHhig) para entender a qué se refiere HTTP encrytion.

# %% [markdown]
# ## Geocoding API request format

# %% [markdown]
# https://maps.googleapis.com/maps/api/geocode/outputFormat?parameters
#
# Donde outputFormat puede tomar los siguientes valores:
# * json (recommended) indicates output in JavaScript Object Notation (JSON); or
# * xml indicates output in XML

# %% [markdown]
# ### Geocoding (latitude/longitude lookup). Parámetros requeridos para hacer el request:

# %% [markdown]
# * address
# * key - Tienen que registrarse, 200 dólares gratis de entrada
# * language
# * region - para paises usando https://en.wikipedia.org/wiki/ISO_3166-1

# %% [markdown]
# **Ejemplo:**
# 1.
# https://maps.googleapis.com/maps/api/geocode/json?address=1600+Amphitheatre+Parkway,+Mountain+View,+CA&key=AIzaSyAJS5pOyd3e3ltMQhi53rfoVL34a0bso44&language=en

# %% [markdown]
# 2. https://maps.googleapis.com/maps/api/geocode/json?address=Avenida+Alfonso+Ugarte+1227,+Cercado+de+Lima+15001&key=AIzaSyAJS5pOyd3e3ltMQhi53rfoVL34a0bso44&language=es

# %% [markdown]
# 2. https://maps.googleapis.com/maps/api/geocode/json?address=Avenida+Alfonso+Ugarte+1227,+Cercado+de+Lima+15001&key=AIzaSyAJS5pOyd3e3ltMQhi53rfoVL34a0bso44&language=es&region=peru

# %% [markdown]
# **Google** :
# _El geocodificador hace todo lo posible para proporcionar una dirección postal que sea
# legible tanto para el usuario como para los lugareños. Para lograr ese objetivo,
# devuelve las direcciones de las calles en el idioma local, transcrito a un guión legible
# por el usuario si es necesario, observando el idioma preferido. Todas las demás direcciones
# se devuelven en el idioma preferido. Todos los componentes de la dirección se devuelven en
# el mismo idioma, que se elige del primer componente._

# %% [markdown]
# ## Ejemplo con data Suiza

# %%
# Packages
import pandas as pd
import os
import urllib.request, json
import csv
import numpy as np
from tqdm import tqdm_notebook as tqdm

# %% [markdown]
# # Camino 1

# %%
with open(r'C:\Users\MSI-NB\Documents\GitHub\The_Code_Blinders\1_Clases\Clase_13\ID_Routes_firms.csv' ,encoding="utf8", errors='ignore') as csvfile:
    readCSV = csv.reader(csvfile, delimiter=',')
    town = []
    
    for row in readCSV:
        gem = row[6]
        town.append(gem)

# %%
# Package for google maps
import googlemaps
from datetime import datetime

# %%
gmaps = googlemaps.Client(key='AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE')

# %%
geocode_result = gmaps.geocode(address= "Humachuco, la libertad,Peru " , region='pe', language = 'es')

# %%
geocode_result
# Out:
# [{'address_components': [{'long_name': 'Huamachuco',
#     'short_name': 'Huamachuco',
#     'types': ['locality', 'political']},
#    {'long_name': 'Sanchez Carrión',
#     'short_name': 'Sanchez Carrión',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'La Libertad',
#     'short_name': 'La Libertad',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'Perú',
#     'short_name': 'PE',
#     'types': ['country', 'political']}],
#   'formatted_address': 'Huamachuco, Perú',
#   'geometry': {'bounds': {'northeast': {'lat': -7.802629899999999,
#      'lng': -78.01863039999999},
#     'southwest': {'lat': -7.844485700000001, 'lng': -78.0576897}},
#    'location': {'lat': -7.816460999999999, 'lng': -78.0452048},
#    'location_type': 'APPROXIMATE',
#    'viewport': {'northeast': {'lat': -7.802629899999999,
#      'lng': -78.01863039999999},
#     'southwest': {'lat': -7.844485700000001, 'lng': -78.0576897}}},
#   'place_id': 'ChIJgWXjTuvkrZERq8lqW7sVpzM',
#   'types': ['locality', 'political']}]

# %%
geocode_result[0]['geometry']['location']['lat']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-e1a8c93d5d22> in <module>
# ----> 1 geocode_result[0]['geometry']['location']['lat']
#
# IndexError: list index out of range

# %%
type(geocode_result)
# Out:
# list

# %%
geocode_result[0]['geometry']['location']['lat']
# Out:
# -12.0553202

# %%
geocode_result[0]['geometry']['location']['lng']
# Out:
# -77.0411721

# %%
# Create a matrix 
coord = np.zeros(shape=(len(town),2), dtype =float)
coord.shape

# %%
i = 0
for t in tqdm(town):
    
    gmaps = googlemaps.Client(key='AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE')
        
    # Geocoding an address
    geocode_result = gmaps.geocode(address = t  , region='ch')

    coord[i][0] = geocode_result[0]['geometry']['location']['lat']
    coord[i][1] = geocode_result[0]['geometry']['location']['lng']
    
    i = i+1
# Out:
# <ipython-input-43-d925297de5a9>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for t in tqdm(town):
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=438.0), HTML(value='')))

# %%
coord
# Out:
# array([[47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.3768866,  8.541694 ],
#        [47.2682174,  8.8191356],
#        [47.6660626,  8.6160024],
#        [47.6660626,  8.6160024],
#        [47.6660626,  8.6160024],
#        [47.4458065,  8.4051088],
#        [47.4053885,  8.39977  ],
#        [47.4251986,  8.6162283],
#        [47.4910721,  8.8665461],
#        [47.4910721,  8.8665461],
#        [47.6885343,  8.6497285],
#        [47.6885343,  8.6497285],
#        [47.6885343,  8.6497285],
#        [47.685357 ,  8.6294367],
#        [47.685357 ,  8.6294367],
#        [47.685357 ,  8.6294367],
#        [47.685357 ,  8.6294367],
#        [47.685357 ,  8.6294367],
#        [47.5313791,  8.5851744],
#        [47.5313791,  8.5851744],
#        [47.5213595,  8.8890608],
#        [47.5213595,  8.8890608],
#        [47.1755749,  8.664826 ],
#        [47.1755749,  8.664826 ],
#        [47.1755749,  8.664826 ],
#        [47.1755749,  8.664826 ],
#        [47.1755749,  8.664826 ],
#        [47.4445367,  8.3868213],
#        [47.4272742,  8.6903376],
#        [47.4272742,  8.6903376],
#        [47.2273614,  8.5268129],
#        [47.2273614,  8.5268129],
#        [47.2273614,  8.5268129],
#        [47.2273614,  8.5268129],
#        [47.2273614,  8.5268129],
#        [47.4495116,  8.5821648],
#        [47.22365  ,  8.46278  ],
#        [47.22365  ,  8.46278  ],
#        [47.22365  ,  8.46278  ],
#        [47.22365  ,  8.46278  ],
#        [47.6700922,  8.6362791],
#        [47.6700922,  8.6362791],
#        [47.6700922,  8.6362791],
#        [47.2574625,  8.6946733],
#        [47.2574625,  8.6946733],
#        [47.6020263,  9.0019686],
#        [47.6020263,  9.0019686],
#        [47.4493246,  9.0498296],
#        [47.655571 ,  9.1312081],
#        [47.4515396,  9.0343854],
#        [46.186706 ,  8.7443382],
#        [46.5196535,  6.6322734],
#        [46.5196535,  6.6322734],
#        [46.5196535,  6.6322734],
#        [46.5196535,  6.6322734],
#        [46.5196535,  6.6322734],
#        [46.5191267,  6.6789123],
#        [46.5191267,  6.6789123],
#        [46.5191267,  6.6789123],
#        [46.4647104,  6.8946536],
#        [46.4647104,  6.8946536],
#        [46.7265588,  6.8955942],
#        [46.4725243,  6.8482854],
#        [46.7082946,  6.8831226],
#        [46.6410996,  6.6344508],
#        [46.5352022,  6.5418995],
#        [46.5457329,  6.86271  ],
#        [46.5296363,  6.5615252],
#        [46.5296363,  6.5615252],
#        [46.5296363,  6.5615252],
#        [46.4203001,  6.2698809],
#        [46.4203001,  6.2698809],
#        [46.4826453,  6.8470796],
#        [46.5396202,  6.8118613],
#        [46.6917509,  6.8639494],
#        [46.5088803,  6.6827638],
#        [46.5088803,  6.6827638],
#        [46.4312213,  6.9106799],
#        [46.4312213,  6.9106799],
#        [46.4312213,  6.9106799],
#        [46.4312213,  6.9106799],
#        [46.5088127,  6.4961301],
#        [46.5088127,  6.4961301],
#        [46.3832683,  6.2347852],
#        [46.3832683,  6.2347852],
#        [46.5547204,  6.8297563],
#        [46.5175835,  6.5252682],
#        [46.5175835,  6.5252682],
#        [46.6997998,  6.8814659],
#        [46.5092681,  6.6654949],
#        [46.5092681,  6.6654949],
#        [46.53381  ,  6.59137  ],
#        [46.4717185,  6.8767709],
#        [46.728    ,  6.87861  ],
#        [46.57147  ,  6.77879  ],
#        [46.310046 ,  6.1735347],
#        [46.310046 ,  6.1735347],
#        [46.310046 ,  6.1735347],
#        [46.4628333,  6.8419192],
#        [46.71921  ,  6.89887  ],
#        [46.7484013,  6.9129687],
#        [46.7784736,  6.641183 ],
#        [46.7784736,  6.641183 ],
#        [46.2710282,  6.9459483],
#        [46.2244777,  7.303512 ],
#        [46.2244777,  7.303512 ],
#        [46.9899874,  6.9292732],
#        [46.9899874,  6.9292732],
#        [46.9899874,  6.9292732],
#        [46.98504  ,  6.8723478],
#        [46.98504  ,  6.8723478],
#        [47.1034892,  6.8327838],
#        [47.1034892,  6.8327838],
#        [46.90449  ,  6.5841256],
#        [46.90449  ,  6.5841256],
#        [46.90449  ,  6.5841256],
#        [46.90449  ,  6.5841256],
#        [46.2043907,  6.1431577],
#        [46.2043907,  6.1431577],
#        [46.2043907,  6.1431577],
#        [46.2043907,  6.1431577],
#        [46.2043907,  6.1431577],
#        [46.2043907,  6.1431577],
#        [46.2043907,  6.1431577],
#        [46.2043907,  6.1431577],
#        [46.1829674,  6.1378539],
#        [46.1829674,  6.1378539],
#        [46.3504128,  6.1952524],
#        [46.3504128,  6.1952524],
#        [46.2715983,  6.125981 ],
#        [46.224552 ,  6.1827372],
#        [46.3006983,  6.2449688],
#        [46.3006983,  6.2449688],
#        [46.2347656,  6.2652187],
#        [46.2347656,  6.2652187],
#        [46.1885168,  6.1144546],
#        [46.1885168,  6.1144546],
#        [46.2283204,  6.070988 ],
#        [46.1553483,  6.0945809],
#        [46.2122638,  6.1052686],
#        [47.1774878,  6.9052937],
#        [47.1774878,  6.9052937]])

# %%
geocode_result = gmaps.

# %%
geocode(address= "colegio guadalupe, cercado de lima" , region='pe', language = 'es')
# Out:
# (438, 2)
