# %%
"""
Created on Tue Jan  1 18:24:50 2019

@author: Alexander
EXTRACT CSV FILES INFO INTO LIST
"""
"""
Simple Program to help you get started with Google's APIs
https://www.youtube.com/watch?v=9N6a-VLBa2I
https://realpython.com/python-json/
https://realpython.com/python-itertools/
https://github.com/googlemaps/google-maps-services-python
"""
import pandas as pd
import os
import urllib.request, json
import csv
import numpy as np
from tqdm import tqdm_notebook as tqdm

# %%
import chardet

rawdata = open('ID_Routes_firms_gps_final.csv', 'rb').read()
result = chardet.detect(rawdata)
charenc = result['encoding']
print(charenc)
# Out:
# UTF-8-SIG

# %%
# Import the csv file
geodata = pd.read_csv( r'ID_Routes_firms_gps_final.csv' , delimiter = ';' , header = None , encoding = charenc)

# Change names of main variables
geodata = geodata.rename( columns = {    geodata.columns[ 0 ] : 'combination', \
                                         geodata.columns[ 10 ] : 'origen', \
                                         geodata.columns[ 11 ] : 'destine', \
                                    } )
geodata
# Out:
#      combination     1     2     3     4               5           6  \
# 0              1  1401   261   699     1         Alpnach    Obwalden
# 1              2  1507   261   712     1  Hergiswil (NW)   Nidwalden
# 2              3  3943   261  1347     1        Mastrils  Graubünden
# 3              4  5236   261  1802     1   Collina d'Oro      Tessin
# 4              5  5192   261  1837     1          Lugano      Tessin
# ..           ...   ...   ...   ...   ...             ...         ...
# 433          434  5635  6630  2043  2514   Ecublens (VD)       Waadt
# 434          435  6621  6632  2485  2516          Genève        Genf
# 435          436  6615  6643  2500  2527    Collex-Bossy        Genf
# 436          437  6608  6742  2493  2567    Carouge (GE)        Genf
# 437          438  6741  6742  2565  2567       Le Bémont        Jura
#
#                  7              8   9                origen  \
# 0           Zürich         Zürich NaN  46.9380412,8.2701754
# ...

# %%
# let´s create the dictionary where data will be saved
data_distance = {}

# %%
# this loop generates the information for distances, time, and traffic information 

for index,row in tqdm(geodata.iterrows()):
    try:
        #Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

        # Requests using traffic information are billed at a higher rate
        # https://developers.google.com/maps/documentation/directions/usage-and-billing

        # Only available for driving , currently time or future / best_guess pessimistic optimistic
        # traffic = '&departure_time=now'

        traffic_model = 'best_guess'  

        departure_time= 'now'

        # driving, walking, biclycling, transit
        mode = 'driving'

        # key
        api_key = 'AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE'

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region= 'ch'

        # Asks the user to input Where they are and where they want to go.
        # origin = input('Where are you?: ').replace(' ','+')
        # destination = input('Where do you want to go?: ').replace(' ','+')
        origin = row['origen']
        destination = row['destine']
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        my_keys = ['distance', 'duration', 'duration_in_traffic']
        info = { my_key: legs[my_key] for my_key in my_keys }
        #print(info)
        #type(info)
        data_distance[row['combination']] = info 
    except Exception as e:
        print
        data_distance[row['combination']] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(row['combination'])
        #break
# Out:
# <ipython-input-46-741d4da38781>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for index,row in tqdm(geodata.iterrows()):
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-741d4da38781> in <module>
#      36
#      37         #Sends the request and reads the response.
# ---> 38         response = urllib.request.urlopen(request).read()
#      39
#      40         #Loads response as JSON
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
# ...

# %%
combination = geodata['combination'].tolist()
origen = geodata['origen'].tolist()
destination = geodata['destine'].tolist()

# %%
# let´s create the dictionary where data will be saved
data_distance = {}

# %%
# this loop generates the information for distances, time, and traffic information 

for c,o,d in tqdm(list(zip(combination,origen, destination))):
    try:
        #Google MapsDdirections API endpoint
        endpoint = 'https://maps.googleapis.com/maps/api/directions/json?'

        # Requests using traffic information are billed at a higher rate
        # https://developers.google.com/maps/documentation/directions/usage-and-billing

        # Only available for driving , currently time or future / best_guess pessimistic optimistic
        # traffic = '&departure_time=now'

        traffic_model = 'best_guess'  

        #departure_time= 'now'

        # driving, walking, biclycling, transit
        mode = 'now'

        # key
        api_key = 'AIzaSyD_4E6Hd-fYECy3mZ4asxN23JjIstvLdoE'

        # region to look for (spain= es , germany = de , Switzerland= swiss)
        region= 'ch'

        # Asks the user to input Where they are and where they want to go.
        # origin = input('Where are you?: ').replace(' ','+')
        # destination = input('Where do you want to go?: ').replace(' ','+')
        origin = o
        destination = d
        #Building the URL for the request
        nav_request = 'origin={}&destination={}&departure_time={}&traffic_model={}&mode={}&region={}&key={}'.format(origin , 
                        destination , departure_time , traffic_model , mode, region, api_key)
        request = endpoint + nav_request

        #Sends the request and reads the response.
        response = urllib.request.urlopen(request).read()

        #Loads response as JSON
        directions = json.loads(response)
        #print(json.dumps(directions, indent = 2))

        legs = directions['routes'][0]['legs'][0]
        my_keys = ['distance', 'duration', 'duration_in_traffic']
        info = { my_key: legs[my_key] for my_key in my_keys }
        #print(info)
        #type(info)
        data_distance[c] = info 
    except Exception as e:
        print
        data_distance[c] = {'distance': {'text': 'nan', 'value': 0}, 'duration': {'text': 'nan', 'value': 0}, 'duration_in_traffic': {'text': 'nan', 'value': 0}}
        print(c)
        #break
# Out:
# <ipython-input-50-1460f3bdaa35>:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for c,o,d in tqdm(list(zip(combination,origen, destination))):
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-1460f3bdaa35> in <module>
#      36
#      37         #Sends the request and reads the response.
# ---> 38         response = urllib.request.urlopen(request).read()
#      39
#      40         #Loads response as JSON
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523
# ...

# %%
print(info)
# Out:
# {'distance': {'text': '11.4 km', 'value': 11449}, 'duration': {'text': '14 mins', 'value': 861}, 'duration_in_traffic': {'text': '13 mins', 'value': 782}}

# %%
print(data_distance)
# Out:
# {1: {'distance': {'text': '65.0 km', 'value': 65002}, 'duration': {'text': '49 mins', 'value': 2952}, 'duration_in_traffic': {'text': '45 mins', 'value': 2720}}, 2: {'distance': {'text': '58.1 km', 'value': 58099}, 'duration': {'text': '43 mins', 'value': 2581}, 'duration_in_traffic': {'text': '41 mins', 'value': 2430}}, 3: {'distance': {'text': '106 km', 'value': 106496}, 'duration': {'text': '1 hour 12 mins', 'value': 4337}, 'duration_in_traffic': {'text': '1 hour 10 mins', 'value': 4188}}, 4: {'distance': {'text': '211 km', 'value': 211486}, 'duration': {'text': '2 hours 35 mins', 'value': 9308}, 'duration_in_traffic': {'text': '2 hours 30 mins', 'value': 8987}}, 5: {'distance': {'text': '207 km', 'value': 207102}, 'duration': {'text': '2 hours 35 mins', 'value': 9286}, 'duration_in_traffic': {'text': '2 hours 29 mins', 'value': 8911}}, 6: {'distance': {'text': '219 km', 'value': 218928}, 'duration': {'text': '2 hours 22 mins', 'value': 8549}, 'duration_in_traffic': {'text': '2 ho
# ...

# %%
e = pd.DataFrame.from_dict(data_distance , orient='index')

# %%
e.index = e.index.astype(int)
e = e.sort_index()
e
# Out:
#                                distance  \
# 1   {'text': '65.0 km', 'value': 65002}
# 2   {'text': '58.1 km', 'value': 58099}
# 3   {'text': '106 km', 'value': 106496}
# 4   {'text': '211 km', 'value': 211486}
# 5   {'text': '207 km', 'value': 207102}
# 6   {'text': '219 km', 'value': 218928}
# 7   {'text': '206 km', 'value': 205920}
# 8   {'text': '206 km', 'value': 206212}
# 9   {'text': '284 km', 'value': 283751}
# 10  {'text': '53.3 km', 'value': 53315}
# 11  {'text': '78.1 km', 'value': 78088}
# 12  {'text': '148 km', 'value': 148229}
# 13    {'text': '6.5 km', 'value': 6498}
# 14  {'text': '15.7 km', 'value': 15711}
# 15  {'text': '13.0 km', 'value': 12975}
# 16  {'text': '233 km', 'value': 233420}
# 17  {'text': '35.8 km', 'value': 35813}
# 18          {'text': '1 m', 'value': 0}
# 19  {'text': '50.4 km', 'value': 50384}
# 20  {'text': '23.8 km', 'value': 23770}
# 21  {'text': '80.9 km', 'value': 80860}
# 22  {'text': '48.5 km', 'value': 48513}
# ...
